# %% [markdown]
# # Demo of `pytikz`, a Python interface to Ti*k*Z
#
# using the examples from the PGF/Ti*k*Z manual

# %%
from tikz import *

# %%
pic = Picture()
# align coordinate system with font metrics
pic.tikzset(x='1ex', y='1ex')
# adjust the space around the contents
pic.clip((-0.215, -1.2), rectangle((6.6, 1.74)))
# remove space around node text
pic.tikzstyle('every node', inner_sep=0, outer_sep=0)
pic.draw(
    # 'p'
    (0, -1), lineto((0, 1)), curveto((0, 0), control1=(0.9, 1.1), control2=(0.9, -0.1)),
    options(xshift='1ex'),
    # 'y'
    (0, 1), curveto((0.7, 0), control1=(0, 0)),
    (0.7, 1), lineto((0.7, 0)), curveto((0, -1), control1=(0.7, -1)),
    options(xshift='0.8ex'),
    # 'TikZ'
    (0, 0), node(r'Ti\emph{\color{orange}k}Z', anchor='base west'),
    darkgray=True, line_cap='round', semithick=True)
pic.draw(
    # points on 'p'
    (0, -1), circle(radius='0.25pt'),
    (0, 1), circle(radius='0.25pt'),
    (0, 0), circle(radius='0.25pt'),
    options(xshift='1ex'),
    # point on 'y'
    (0, 1), circle(radius='0.25pt'),
    (0.7, 0), circle(radius='0.25pt'),
    (0.7, 1), circle(radius='0.25pt'),
    (0, -1), circle(radius='0.25pt'),
    ultra_thin=True, fill='white')

pic.demo(dpi=1200)
pic.write_image('pytikz.png', dpi=1200)
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \tikzset{x=1ex,y=1ex}
# \clip (-0.215,-1.2) rectangle (6.6,1.74);
# \tikzset{every node/.style={inner sep=0,outer sep=0}}
# \draw[darkgray,line cap=round,semithick] (0,-1) -- (0,1) .. controls (0.9,1.1) and (0.9,-0.1) .. (0,0) [xshift=1ex] (0,1) .. controls (0,0) .. (0.7,0) (0.7,1) -- (0.7,0) .. controls (0.7,-1) .. (0,-1) [xshift=0.8ex] (0,0) node[anchor=base west] {Ti\emph{\color{orange}k}Z};
# \draw[ultra thin,fill=white] (0,-1) circle[radius=0.25pt] (0,1) circle[radius=0.25pt] (0,0) circle[radius=0.25pt] [xshift=1ex] (0,1) circle[radius=0.25pt] (0.7,0) circle[radius=0.25pt] (0.7,1) circle[radius=0.25pt] (0,-1) circle[radius=0.25pt];
# \end{tikzpicture}</pre>
#   </div>
# ...

# %% [markdown]
# ## from the prelude of "Part I: Tutorials and Guidelines"

# %%
# "Das ist das Haus vom Nikolaus"

points = [(0, 0), (0, 2), (1, 3.25), (2, 2), (2, 0), (0, 2), (2, 2), (0, 0), (2, 0)]

pic = Picture()
pic.draw(line(points), thick=True, rounded_corners='4pt')

# %%
# `.code()` returns the LaTeX/TikZ code of the picture
print(pic.code())
# Out:
# \begin{tikzpicture}
# \draw[thick,rounded corners=4pt] (0,0) -- (0,2) -- (1,3.25) -- (2,2) -- (2,0) -- (0,2) -- (2,2) -- (0,0) -- (2,0);
# \end{tikzpicture}

# %%
# evaluating the picture in the notebook uses `_repr_png_`, which returns an Image object
pic

# %%
# the convenience function `demo` shows both the image and the code
pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw[thick,rounded corners=4pt] (0,0) -- (0,2) -- (1,3.25) -- (2,2) -- (2,0) -- (0,2) -- (2,2) -- (0,0) -- (2,0);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.2.1 Setting up the Environment in LaTeX"

# %%
a = 1.5

pic = Picture()
pic.draw((-a, 0), lineto((a, 0)))
pic.draw((0, -a), lineto((0, a)))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.4 Curved Path Construction"

# %%
p1 = (0, 0)
c1 = (1, 1)
c2 = (2, 1)
p2 = (2, 0)

pic = Picture()
pic.filldraw(
    p1, circle(radius='2pt'),
    c1, circle(radius='2pt'),
    c2, circle(radius='2pt'),
    p2, circle(radius='2pt'),
    gray=True)
pic.draw(p1, curveto(p2, control1=c1, control2=c2))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \filldraw[gray] (0,0) circle[radius=2pt] (1,1) circle[radius=2pt] (2,1) circle[radius=2pt] (2,0) circle[radius=2pt];
# \draw (0,0) .. controls (1,1) and (2,1) .. (2,0);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture()
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((-1, 0), curveto((0, 1), control1=(-1, 0.555), control2=(-0.555, 1)),
    curveto((1, 0), control1=(0.555, 1), control2=(1, 0.555)))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (-1,0) .. controls (-1,0.555) and (-0.555,1) .. (0,1) .. controls (0.555,1) and (1,0.555) .. (1,0);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.5 Circle Path Construction"

# %%
pic = Picture()
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))

pic.draw((0, 0), circle(radius=1))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.6 Rectangle Path Construction"

# %%
pic = Picture()
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))

pic.draw((0, 0), rectangle((0.5, 0.5)))
pic.draw((-0.5, -0.5), rectangle((-1, -1)))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \draw (0,0) rectangle (0.5,0.5);
# \draw (-0.5,-0.5) rectangle (-1,-1);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.7 Grid Path Construction"

# %%
pic = Picture()
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))

pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.10 Arc Path Construction"

# %%
pic = Picture(scale=3)
pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))

pic.draw(('3mm', '0mm'), arc(start_angle=0, end_angle=30, radius='3mm'))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \draw (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm];
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.11 Clipping a Path"

# %%
pic = Picture(scale=3)

pic.clip((-0.1, -0.2), rectangle((1.1, 0.75)))

pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))
pic.draw(('3mm', '0mm'), arc(start_angle=0, end_angle=30, radius='3mm'))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \clip (-0.1,-0.2) rectangle (1.1,0.75);
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \draw (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm];
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture(scale=3)

pic.clip((0.5, 0.5), circle(radius=0.6), opt='draw')

pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))
pic.draw(('3mm', '0mm'), arc(start_angle=0, end_angle=30, radius='3mm'))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \clip[draw] (0.5,0.5) circle[radius=0.6];
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \draw (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm];
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.12 Parabola and Sine Path Construction"

# %%
pic = Picture(scale=3)
pic.draw((0, 0), rectangle((1, 1)), (0, 0), parabola((1, 1)))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \draw (0,0) rectangle (1,1) (0,0) parabola (1,1);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture(scale=3)
pic.draw((0, 0), parabola((6, 12), bend=(4, 16)), x='1pt', y='1pt')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \draw[x=1pt,y=1pt] (0,0) parabola bend (4,16) (6,12);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture(scale=3)
pic.draw((0, 0), sin((1.57, 1)), x='1ex', y='1ex')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \draw[x=1ex,y=1ex] (0,0) sin (1.57,1);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture(scale=3)
pic.draw((0,0), sin((1,1)), cos((2,0)), sin((3,-1)), cos((4,0)),
    (0,1), cos((1,0)), sin((2,-1)), cos((3,0)), sin((4,1)),
    x='1.57ex', y='1ex')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \draw[x=1.57ex,y=1ex] (0,0) sin (1,1) cos (2,0) sin (3,-1) cos (4,0) (0,1) cos (1,0) sin (2,-1) cos (3,0) sin (4,1);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.13 Filling and Drawing"

# %%
pic = Picture(scale=3)
pic.clip((-0.1, -0.2), rectangle((1.1, 0.75)))
pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))

pic.path((0, 0), lineto('(3mm,0mm)'), arc(start_angle=0, end_angle=30, radius='3mm'), lineto(cycle()),
    fill='green!20!white', draw='green!50!black')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \clip (-0.1,-0.2) rectangle (1.1,0.75);
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \path[fill=green!20!white,draw=green!50!black] (0,0) -- (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm] -- cycle;
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.14 Shading"

# %%
pic = Picture(rounded_corners=True, ultra_thick=True)
pic.shade((0, 0), rectangle('+(2, 1)'),
    top_color='yellow', bottom_color='black')
pic.shade((3, 0), rectangle('+(2, 1)'),
    left_color='yellow', right_color='black')
pic.shadedraw((6, 0), rectangle('+(2, 1)'),
    inner_color='yellow', outer_color='black', draw='yellow')
pic.shade((9, 0.5), circle(radius=0.5),
    ball_color='green')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[rounded corners,ultra thick]
# \shade[top color=yellow,bottom color=black] (0,0) rectangle +(2, 1);
# \shade[left color=yellow,right color=black] (3,0) rectangle +(2, 1);
# \shadedraw[inner color=yellow,outer color=black,draw=yellow] (6,0) rectangle +(2, 1);
# \shade[ball color=green] (9,0.5) circle[radius=0.5];
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.15 Specifying Coordinates"

# %%
pic = Picture(scale=3)
pic.clip((-0.1, -0.2), rectangle((1.1, 0.75)))
pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))
pic.path((0, 0), lineto('(3mm,0mm)'), arc(start_angle=0, end_angle=30, radius='3mm'), lineto(cycle()),
    fill='green!20!white', draw='green!50!black')

pic.draw('(30:1)', '--', '(30:1 |- 0,0)', opt='red,very thick')
pic.draw((0,0), '--', '(30:1 |- 0,0)', opt='blue,very thick')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \clip (-0.1,-0.2) rectangle (1.1,0.75);
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \path[fill=green!20!white,draw=green!50!black] (0,0) -- (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm] -- cycle;
# \draw[red,very thick] (30:1) -- (30:1 |- 0,0);
# \draw[blue,very thick] (0,0) -- (30:1 |- 0,0);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.16 Intersecting Paths"

# %%
pic = Picture(scale=3)
pic.clip((-0.1, -0.2), rectangle((1.1, 0.75)))
pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)))
pic.draw((0, -1.5), lineto((0, 1.5)))
pic.draw((0, 0), circle(radius=1))
pic.path((0, 0), lineto('(3mm,0mm)'), arc(start_angle=0, end_angle=30, radius='3mm'), lineto(cycle()),
    fill='green!20!white', draw='green!50!black')
pic.draw('(30:1)', '--', '(30:1 |- 0,0)', opt='red,very thick')
pic.draw((0,0), '--', '(30:1 |- 0,0)', opt='blue,very thick')

pic.usetikzlibrary('intersections')
pic.path((1, 0), lineto((1, 1)), name_path='upward line')
pic.path((0, 0), lineto('(30:1.5)'), name_path='sloped line')
pic.draw((1, 0), lineto('(x)'), name_intersections='{of=upward line and sloped line, by=x}',
    opt='orange,very thick')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \clip (-0.1,-0.2) rectangle (1.1,0.75);
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (-1.5,0) -- (1.5,0);
# \draw (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \path[fill=green!20!white,draw=green!50!black] (0,0) -- (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm] -- cycle;
# \draw[red,very thick] (30:1) -- (30:1 |- 0,0);
# \draw[blue,very thick] (0,0) -- (30:1 |- 0,0);
# \path[name path=upward line] (1,0) -- (1,1);
# \path[name path=sloped line] (0,0) -- (30:1.5);
# \draw[orange,very thick,name intersections={of=upward line and sloped line, by=x}] (1,0) -- (x);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.17 Adding Arrow Tips"

# %%
pic = Picture(scale=3)
#pic.clip((-0.1, -0.2), rectangle((1.1, 1.51)))
pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'), opt='gray,very thin')
pic.draw((-1.5, 0), lineto((1.5, 0)), opt='->')
pic.draw((0, -1.5), lineto((0, 1.5)), opt='->')
pic.draw((0, 0), circle(radius=1))
pic.path((0, 0), lineto('(3mm,0mm)'), arc(start_angle=0, end_angle=30, radius='3mm'), lineto(cycle()),
    fill='green!20!white', draw='green!50!black')
pic.draw('(30:1)', '--', '(30:1 |- 0,0)', opt='red,very thick')
pic.draw((0,0), '--', '(30:1 |- 0,0)', opt='blue,very thick')
pic.usetikzlibrary('intersections')
pic.path((1, 0), lineto((1, 1)), name_path='upward line')
pic.path((0, 0), lineto('(30:1.5)'), name_path='sloped line')
pic.draw((1, 0), lineto('(x)'), name_intersections='{of=upward line and sloped line, by=x}',
    opt='orange,very thick')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3]
# \draw[gray,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw[-&gt;] (-1.5,0) -- (1.5,0);
# \draw[-&gt;] (0,-1.5) -- (0,1.5);
# \draw (0,0) circle[radius=1];
# \path[fill=green!20!white,draw=green!50!black] (0,0) -- (3mm,0mm) arc[start angle=0,end angle=30,radius=3mm] -- cycle;
# \draw[red,very thick] (30:1) -- (30:1 |- 0,0);
# \draw[blue,very thick] (0,0) -- (30:1 |- 0,0);
# \path[name path=upward line] (1,0) -- (1,1);
# \path[name path=sloped line] (0,0) -- (30:1.5);
# \draw[orange,very thick,name intersections={of=upward line and sloped line, by=x}] (1,0) -- (x);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture(opt='>=Stealth')
pic.usetikzlibrary('arrows.meta')
pic.draw((0, 0), arc(start_angle=180, end_angle=30, radius='10pt'), opt='->')
pic.draw((1, 0), lineto(['(1.5cm,10pt)', '(2cm,0pt)', '(2.5cm,10pt)']), opt='<<-,very thick')

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[&gt;=Stealth]
# \draw[-&gt;] (0,0) arc[start angle=180,end angle=30,radius=10pt];
# \draw[&lt;&lt;-,very thick] (1,0) -- (1.5cm,10pt) -- (2cm,0pt) -- (2.5cm,10pt);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %%
pic = Picture(opt='ultra thick')
pic.draw(line([(0, 0), (0, 1)]))
scope = pic.add_scope(thin=True)
scope.draw(line([(1, 0), (1, 1)]))
scope.draw(line([(2, 0), (2, 1)]))
pic.draw(line([(3, 0), (3, 1)]))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[ultra thick]
# \draw (0,0) -- (0,1);
# \begin{scope}[thin]
# \draw (1,0) -- (1,1);
# \draw (2,0) -- (2,1);
# \end{scope}
# \draw (3,0) -- (3,1);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.19 Transformations"

# %%
pic = Picture(even_odd_rule=True,rounded_corners='2pt',x='10pt',y='10pt')
pic.filldraw(options(fill='yellow!80!black'), (0, 0), rectangle((1, 1)),
             options(xshift='5pt', yshift='5pt'), (0, 0), rectangle((1, 1)),
             options(rotate=30), (-1, -1), rectangle((2, 2)))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[even odd rule,rounded corners=2pt,x=10pt,y=10pt]
# \filldraw [fill=yellow!80!black] (0,0) rectangle (1,1) [xshift=5pt,yshift=5pt] (0,0) rectangle (1,1) [rotate=30] (-1,-1) rectangle (2,2);
# \end{tikzpicture}</pre>
#   </div>
#   <div style="clear:both"></div>
# </div>

# %% [markdown]
# ## from "2.20 Repeating Things: For-Loops"

# %%
# The foreach command is not implemented, because it can be replaced by a Python loop,
# albeit at the expense of more verbose tikz code.

pic = Picture()
for x in [1, 2, 3, 4, 5, 7,   8, 9, 10, 11, 12]:
    for y in [1, 2, 3, 4, 5]:
        pic.draw((x, y), '+(-.5,-.5)', rectangle('++(.5,.5)'))
        pic.draw((x, y), node(f'{x},{y}'))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}
# \draw (1,1) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (1,1) node {1,1};
# \draw (1,2) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (1,2) node {1,2};
# \draw (1,3) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (1,3) node {1,3};
# \draw (1,4) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (1,4) node {1,4};
# \draw (1,5) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (1,5) node {1,5};
# \draw (2,1) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (2,1) node {2,1};
# \draw (2,2) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (2,2) node {2,2};
# \draw (2,3) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (2,3) node {2,3};
# \draw (2,4) +(-.5,-.5) rectangle ++(.5,.5);
# \draw (2,4) node {2,4};
# \draw (2,5) +(-.5,-.5) rectangle ++(.5,.5);
# ...

# %% [markdown]
# ## from "2.21 Adding Text"

# %%
pic = Picture(scale=3, line_cap='round')
pic.tikzstyle('axes')
pic.tikzstyle('important line', very_thick=True)

# Colors
pic.colorlet('anglecolor', 'green!50!black')
pic.colorlet('sincolor', 'red')
pic.colorlet('coscolor', 'blue')

# The graphic
pic.draw((-1.4, -1.4), grid((1.4, 1.4), step='0.5cm'),
    help_lines=True, very_thin=True)

pic.draw((0, 0), circle(radius=1))

scope = pic.add_scope(axes=True)
scope.draw((-1.5, 0), lineto((1.5, 0)), node('$x$', right=True), coordinate(name='x axis'),
    opt='->')
scope.draw((0, -1.5), lineto((0, 1.5)), node('$y$', above=True), coordinate(name='y axis'),
    opt='->')

for x in [-1, -0.5, 0, 0.5, 1]:
    scope.draw('(0pt,1pt)', lineto('(0pt,-1pt)'), node(f'${x}$', below=True, fill='white'),
        xshift=f'{x} cm')

for y in [-1, -0.5, 0, 0.5, 1]:
    scope.draw('(1pt,0pt)', lineto('(-1pt,0pt)'), node(f'${y}$', left=True, fill='white'),
        yshift=f'{y} cm')

pic.path((0, 0), lineto('(3mm,0mm)'), arc(start_angle=0, end_angle=30, radius='3mm'), lineto(cycle()),
    fill='green!20', draw='anglecolor')
pic.draw('(15:2mm)', node(r'$\alpha$', anglecolor=True))

pic.draw('(30:1cm)', lineto('(30:1cm |- x axis)'),
    node(r'$\sin \alpha$', left='1pt', fill='white', pos=0.5),
    important_line=True, sincolor=True)

pic.draw('(30:1cm |- x axis)', lineto((0,0)),
    node(r'$\cos \alpha$', below='2pt', fill='white', pos=0.5),
    important_line=True, coscolor=True)

pic.usetikzlibrary('intersections')
pic.path((1, 0), lineto((1, 1)), name_path='upward line')
pic.path((0, 0), lineto('(30:1.5)'), name_path='sloped line')
pic.draw(name_intersections='{of=upward line and sloped line, by=t}')

pic.draw((1, 0), lineto('(t)'), node(
            r"""$
            \displaystyle
            \tan \alpha
            \color{black} = \frac{
                \color{red} \sin \alpha}{
                \color{blue} \cos \alpha}
            $""",
            right='1pt', fill='white', pos=0.5),
        orange=True, very_thick=True)

pic.draw((0, 0), lineto('(t)'))

pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <img style="max-width:47%;padding:10px;float:left"
#       src="data:image/png;base64,...">
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap"
#         >\begin{tikzpicture}[scale=3,line cap=round]
# \tikzset{axes/.style={}}
# \tikzset{important line/.style={very thick}}
# \colorlet{anglecolor}{green!50!black}
# \colorlet{sincolor}{red}
# \colorlet{coscolor}{blue}
# \draw[help lines,very thin] (-1.4,-1.4) grid[step=0.5cm] (1.4,1.4);
# \draw (0,0) circle[radius=1];
# \begin{scope}[axes]
# \draw[-&gt;] (-1.5,0) -- (1.5,0) node[right] {$x$} coordinate (x axis);
# \draw[-&gt;] (0,-1.5) -- (0,1.5) node[above] {$y$} coordinate (y axis);
# \draw[xshift=-1 cm] (0pt,1pt) -- (0pt,-1pt) node[below,fill=white] {$-1$};
# \draw[xshift=-0.5 cm] (0pt,1pt) -- (0pt,-1pt) node[below,fill=white] {$-0.5$};
# \draw[xshift=0 cm] (0pt,1pt) -- (0pt,-1pt) node[below,fill=white] {$0$};
# ...

# %%
# %%html
# <style>
# div.tikzcode pre {
#   white-space: pre-wrap;
#   margin: 0;
#   padding: 0;
#   padding-left: 4ch;
#   text-indent: -4ch;
#   background: lightgray;
# }
# </style>
# <div class="tikzcode">
# <p>This is a piece of code:</p>
# <pre>A line of computer code that is very  very very very very very very very very very very very very very very very very very very very very long.</pre>
# <pre>The second line is short.</pre>
# <pre>The third line is also very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very long.</pre>
# <p>How to properly embed a <code>style</code> element in the notebook?</p>
# </div>
# Out:
# <style>
# div.tikzcode pre {
#   white-space: pre-wrap;
#   margin: 0;
#   padding: 0;
#   padding-left: 4ch;
#   text-indent: -4ch;
#   background: lightgray;
# }
# </style>
# <div class="tikzcode">
# <p>This is a piece of code:</p>
# <pre>A line of computer code that is very  very very very very very very very very very very very very very very very very very very very very long.</pre>
# <pre>The second line is short.</pre>
# <pre>The third line is also very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very long.</pre>
# <p>How to properly embed a <code>style</code> element in the notebook?</p>
# </div>

# %% [markdown]
# [§15.11](https://pgf-tikz.github.io/pgf/pgfmanual.pdf#subsection.15.11)

# %% [markdown]
# - type hinting
# - all docstring triple-quoted, with blank line after
# - docstring for: class (not `__init__`), method, function; package, module
# - variables are documented in the class/module/package docstring
